# %%
import pandas as pd
from TSB_AD.model_wrapper import run_Unsupervise_AD
from TSB_AD.evaluation.metrics import get_metrics

# Specify Anomaly Detector to use and data directory
AD_Name = 'CNN'   # It can be replaced with any anomaly detector availale in TSB-AD
data_direc = '/Users/kai/Documents/Time_Series_Anomaly_Detection_Seminar/Time-Series-Anomaly-Detection-Seminar/TSB-AD/Datasets/TSB-AD-U/001_NAB_id_1_Facility_tr_1007_1st_2014.csv'

# Loading Data
df = pd.read_csv(data_direc).dropna()
data = df.iloc[:, 0:-1].values.astype(float)
label = df['Label'].astype(int).to_numpy()

# Applying Anomaly Detector
output = run_Unsupervise_AD(AD_Name, data)

# Evaluation
evaluation_result = get_metrics(output, label)
# Out:
# An error occurred while running the model 'run_CNN': run_CNN() missing 1 required positional argument: 'data_test'
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[4], line 18
#      15 output = run_Unsupervise_AD(AD_Name, data)
#      17 # Evaluation
# ---> 18 evaluation_result = get_metrics(output, label)
#
# File ~/Documents/Time_Series_Anomaly_Detection_Seminar/Time-Series-Anomaly-Detection-Seminar/TSB-AD/TSB_AD/evaluation/metrics.py:11, in get_metrics(score, labels, slidingWindow, pred, version, thre)
#       9 grader = basic_metricor()
#      10 # AUC_ROC, Precision, Recall, PointF1, PointF1PA, Rrecall, ExistenceReward, OverlapReward, Rprecision, RF, Precision_at_k = grader.metric_new(labels, score, pred, plot_ROC=False)
# ---> 11 AUC_ROC = grader.metric_ROC(labels, score)
#      12 AUC_PR = grader.metric_PR(labels, score)
# ...

# %%
print(evaluation_result)
# Out:
# {'AUC-PR': 0.15269855522128545, 'AUC-ROC': 0.6810639502159712, 'VUS-PR': 0.18474734777662427, 'VUS-ROC': 0.7528825596433526, 'Standard-F1': 0.26405951956918766, 'PA-F1': 0.8542963885429639, 'Event-based-F1': 0.37010676156583594, 'R-based-F1': 0.19703332769196885, 'Affiliation-F': 0.8232591781493652}
